# %% [markdown]
# # Medical Insurance Premium Calculator

# %%
# %run "/Users/gomathilakshmigandhi@gmail.com/Medical_Insurance_Prediction/Day 22 - Feature Importance Analysis"
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- bmi: double (nullable = true)
#  |-- children: integer (nullable = true)
#  |-- smoker: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- charges: double (nullable = true)
#  |-- bmi_category: string (nullable = true)
#  |-- age_group: string (nullable = true)
#  |-- smoker_flag: integer (nullable = true)
#  |-- region_index: double (nullable = true)
#  |-- region_encoded: vectorudt (nullable = true)
#  |-- sex_index: double (nullable = true)
#  |-- sex_encoded: vectorudt (nullable = true)
#  |-- bmi_index: double (nullable = true)
#  |-- bmi_encoded: vectorudt (nullable = true)
#  |-- age_group_index: double (nullable = true)
#  |-- age_group_encoded: vectorudt (nullable = true)
# +-------------------------------------------------+
# |features                                         |
# +-------------------------------------------------+
# ...

# %%
# Customer Details

age = 35
sex = "male"
bmi = 28.5
children = 2
smoker = "yes"
region = "southeast"
# Out:
# dict_keys(['NotebookImportException', 'display', 'displayHTML', 'dbutils', 'udf', 'getArgument', 'sc', 'sqlContext', 'spark', 'table', 'sql', '__name__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_i2', '_i3', 'train_data', '_i4', '_i5', 'VectorAssembler', 'feature_cols', 'assembler', '_i6', '_i7', 'RandomForestRegressor', 'rf', 'rf_model', '_i8', 'feature_importances', '_i9', '_i10', '_i11', '_i12', '_i13', '_i14', 'pd', 'feature_names', 'importance_df', '_14', '_i15', 'plt', '_i16', '_i17', 'df', '_i18', '_i19', '__instrument_exception_types', '__builtins_import_patcher', '__dataframe_expression_watcher', '_i20'])
# RandomForestRegressionModel: uid=RandomForestRegressor_748bbe125ae7, numTrees=100, numFeatures=13
# ['age',
#  'bmi',
#  'children',
#  'smoker_flag',
#  'region_encoded',
#  'sex_encoded',
#  'bmi_encoded',
#  'age_group_encoded']
# <style scoped>
# ...

# %%
# Encode smoker

smoker_flag = 1 if smoker == "yes" else 0

# Encode sex

sex_encoded = 1 if sex == "male" else 0

# Encode region

region_map = {
    "northeast": 0,
    "northwest": 1,
    "southeast": 2,
    "southwest": 3
}

region_encoded = region_map[region]

# %%
if bmi < 18.5:
    bmi_encoded = 0
elif bmi < 25:
    bmi_encoded = 1
elif bmi < 30:
    bmi_encoded = 2
else:
    bmi_encoded = 3

# %%
if age < 30:
    age_group_encoded = 0
elif age < 45:
    age_group_encoded = 1
elif age < 60:
    age_group_encoded = 2
else:
    age_group_encoded = 3

# %%
input_data = spark.createDataFrame(
    [(
        age,
        bmi,
        children,
        smoker_flag,
        region_encoded,
        sex_encoded,
        bmi_encoded,
        age_group_encoded
    )],
    [
        "age",
        "bmi",
        "children",
        "smoker_flag",
        "region_encoded",
        "sex_encoded",
        "bmi_encoded",
        "age_group_encoded"
    ]
)

display(input_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>bmi</th><th>children</th><th>smoker_flag</th><th>region_encoded</th><th>sex_encoded</th><th>bmi_encoded</th><th>age_group_encoded</th></tr></thead><tbody><tr><td>35</td><td>28.5</td><td>2</td><td>1</td><td>2</td><td>1</td><td>2</td><td>1</td></tr></tbody></table></div>

# %%
feature_cols = [
    "age",
    "bmi",
    "children",
    "smoker_flag",
    "region_encoded",
    "sex_encoded",
    "bmi_encoded",
    "age_group_encoded"
]

# %%
from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(
    inputCols=feature_cols,
    outputCol="features"
)

input_features = assembler.transform(input_data)

# %%
print(assembler.getInputCols())
# Out:
# ['age', 'bmi', 'children', 'smoker_flag', 'region_encoded', 'sex_encoded', 'bmi_encoded', 'age_group_encoded']

# %%
input_features.select("features").show(truncate=False)
# Out:
# +-----------------------------------+
# |features                           |
# +-----------------------------------+
# |[35.0,28.5,2.0,1.0,2.0,1.0,2.0,1.0]|
# +-----------------------------------+

# %%
print(rf_model.numFeatures)
# Out:
# 13

# %%
prediction = rf_model.transform(input_features)

# %%
print(feature_cols)
print(len(feature_cols))
# Out:
# ['age', 'bmi', 'children', 'smoker_flag', 'region_encoded', 'sex_encoded', 'bmi_encoded', 'age_group_encoded']
# 8

# %%
globals().keys()
# Out:
# dict_keys(['NotebookImportException', 'display', 'displayHTML', 'dbutils', 'udf', 'getArgument', 'sc', 'sqlContext', 'spark', 'table', 'sql', '__name__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_i2', '_i3', 'train_data', '_i4', '_i5', 'VectorAssembler', 'feature_cols', 'assembler', '_i6', '_i7', 'RandomForestRegressor', 'rf', 'rf_model', '_i8', 'feature_importances', '_i9', '_i10', '_i11', '_i12', '_i13', '_i14', 'pd', 'feature_names', 'importance_df', '_14', '_i15', 'plt', '_i16', '_i17', 'df', '_i18', '_i19', '_i20', '_20', '_i21', '_i22', '_22', '_i23', 'sample_data', 'columns', 'sample_df', '_i24', 'sample_features', '_i25', '_25', '_i26', '_i27', '_27', '_i28', '_i29', '_29', '_i30', '_i31', 'sample_customers', '_i32', 'predictions', '_i33', '_33', '_i34', 'importance_values', '_i35', 'age', 'sex', 'bmi', 'children', 'smoker', 'region', '_i36', 'smoker_flag', 'sex_encod
# ...

# %%
print(assembler.getInputCols())
print(len(assembler.getInputCols()))
# Out:
# ['age', 'bmi', 'children', 'smoker_flag', 'region_encoded', 'sex_encoded', 'bmi_encoded', 'age_group_encoded']
# 8

# %%
feature_names
# Out:
# ['age',
#  'bmi',
#  'children',
#  'smoker_flag',
#  'region_encoded',
#  'sex_encoded',
#  'bmi_encoded',
#  'age_group_encoded']

# %%
from pyspark.ml.regression import RandomForestRegressor

new_rf = RandomForestRegressor(
    featuresCol="features",
    labelCol="charges",
    numTrees=100
)

new_rf_model = new_rf.fit(train_data)

# %%
train_data.select("features").show(5, truncate=False)
# Out:
# +-------------------------------------------------+
# |features                                         |
# +-------------------------------------------------+
# |(13,[0,1,4,10,12],[18.0,20.79,1.0,1.0,1.0])      |
# |(13,[0,1,3,10,12],[18.0,21.66,1.0,1.0,1.0])      |
# |(13,[0,1,2,4,10,12],[18.0,24.09,1.0,1.0,1.0,1.0])|
# |(13,[0,1,9,12],[18.0,25.08,1.0,1.0])             |
# |(13,[0,1,9,12],[18.0,26.315,1.0,1.0])            |
# +-------------------------------------------------+
# only showing top 5 rows

# %%
train_data.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- bmi: double (nullable = true)
#  |-- children: integer (nullable = true)
#  |-- smoker: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- charges: double (nullable = true)
#  |-- bmi_category: string (nullable = true)
#  |-- age_group: string (nullable = true)
#  |-- smoker_flag: integer (nullable = true)
#  |-- region_index: double (nullable = true)
#  |-- region_encoded: vectorudt (nullable = true)
#  |-- sex_index: double (nullable = true)
#  |-- sex_encoded: vectorudt (nullable = true)
#  |-- bmi_index: double (nullable = true)
#  |-- bmi_encoded: vectorudt (nullable = true)
#  |-- age_group_index: double (nullable = true)
#  |-- age_group_encoded: vectorudt (nullable = true)
#  |-- features: vectorudt (nullable = true)

# %%
from pyspark.ml.feature import VectorAssembler

feature_cols = [
    'age',
    'bmi',
    'children',
    'smoker_flag',
    'region_encoded',
    'sex_encoded',
    'bmi_encoded',
    'age_group_encoded'
]

assembler = VectorAssembler(
    inputCols=feature_cols,
    outputCol="features"
)

train_data_new = assembler.transform(df)

# %%
from pyspark.ml.regression import RandomForestRegressor

new_rf = RandomForestRegressor(
    featuresCol="features",
    labelCol="charges",
    numTrees=100
)

new_rf_model = new_rf.fit(train_data_new)
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# File <command-8148561232084121>, line 9
#       1 from pyspark.ml.regression import RandomForestRegressor
#       3 new_rf = RandomForestRegressor(
#       4     featuresCol="features",
#       5     labelCol="charges",
#       6     numTrees=100
#       7 )
# ----> 9 new_rf_model = new_rf.fit(train_data_new)
#
# File /databricks/python_shell/lib/dbruntime/MLWorkloadsInstrumentation/_pyspark.py:30, in _create_patch_function.<locals>.patched_method(self, *args, **kwargs)
#      28 call_succeeded = False
#      29 try:
# ---> 30     result = original_method(self, *args, **kwargs)
#      31     call_succeeded = True
#      32     return result
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/ml/base.py:203, in Estimator.fit(self, dataset, params)
#     201         return self.copy(params)._fit(dataset)
# ...

# %%
df.columns

# %%
print(new_rf_model.numFeatures)

# %%
from pyspark.ml.feature import StringIndexer

sex_indexer = StringIndexer(
    inputCol="sex",
    outputCol="sex_index"
).fit(df)

smoker_indexer = StringIndexer(
    inputCol="smoker",
    outputCol="smoker_index"
).fit(df)

region_indexer = StringIndexer(
    inputCol="region",
    outputCol="region_index"
).fit(df)

df2 = sex_indexer.transform(df)
df2 = smoker_indexer.transform(df2)
df2 = region_indexer.transform(df2)

display(df2)

# %%
from pyspark.ml.feature import VectorAssembler

feature_cols = [
    "age",
    "bmi",
    "children",
    "sex_index",
    "smoker_index",
    "region_index"
]

assembler = VectorAssembler(
    inputCols=feature_cols,
    outputCol="features"
)

train_data_new = assembler.transform(df2)

display(train_data_new.select("features"))

# %%
from pyspark.ml.regression import RandomForestRegressor

rf = RandomForestRegressor(
    featuresCol="features",
    labelCol="charges",
    numTrees=100
)

new_rf_model = rf.fit(train_data_new)

print(new_rf_model.numFeatures)

# %%
sample_customers = spark.createDataFrame([
    (25, "female", 22.5, 0, "no", "southeast"),
    (40, "male", 30.0, 2, "yes", "northeast"),
    (55, "female", 35.0, 1, "no", "northwest")
], ["age", "sex", "bmi", "children", "smoker", "region"])

# %%
sample_customers = sex_indexer.transform(sample_customers)
sample_customers = smoker_indexer.transform(sample_customers)
sample_customers = region_indexer.transform(sample_customers)

input_features = assembler.transform(sample_customers)

# %%
predictions = new_rf_model.transform(input_features)

display(
    predictions.select(
        "age",
        "sex",
        "bmi",
        "children",
        "smoker",
        "region",
        "prediction"
    )
)

# %%
display(
    predictions.select(
        "age",
        "sex",
        "bmi",
        "children",
        "smoker",
        "region",
        "prediction"
    )
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(
    predictions.select(
        "age",
        "prediction"
    )
)

# %% [markdown]
# # Day 26 – Premium Calculator
#
# ## Objective
# Predict insurance premiums for new customers using the trained Random Forest model.
#
# ## Steps Performed
# 1. Encoded categorical variables.
# 2. Created feature vectors using VectorAssembler.
# 3. Trained Random Forest Regression model.
# 4. Created sample customer records.
# 5. Generated premium predictions.
# 6. Visualized predicted premiums.
#
# ## Result
# The model successfully predicted insurance premiums for new customers. Smoking status had the greatest impact on predicted premium values.
