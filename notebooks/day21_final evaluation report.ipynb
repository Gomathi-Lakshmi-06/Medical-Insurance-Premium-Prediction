# %%
r2_rf = 0.8727228514327479
rmse_rf = 4114.599051379543
mae_rf = 2597.4317232836697

print("Final Model: Random Forest Regressor")
print("R2 Score :", r2_rf)
print("RMSE :", rmse_rf)
print("MAE :", mae_rf)
# Out:
# Final Model: Random Forest Regressor
# R2 Score : 0.8727228514327479
# RMSE : 4114.599051379543
# MAE : 2597.4317232836697

# %%
comparison = [
    ("Linear Regression", 0.7504),
    ("Gradient Boosting", 0.8063),
    ("Random Forest", 0.8727)
]

for model, score in comparison:
    print(model, ":", score)
# Out:
# Linear Regression : 0.7504
# Gradient Boosting : 0.8063
# Random Forest : 0.8727
